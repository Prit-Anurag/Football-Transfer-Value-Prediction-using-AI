# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv("Injury Raw Data.csv")

# %%
df.head(3)
# Out:
#             p_id2  start_year  season_days_injured  total_days_injured  \
# 0   aaronconnolly        2019                   13                 161
# 1   aaronconnolly        2020                   71                 161
# 2  aaroncresswell        2016                   95                 226
#
#    season_minutes_played  season_games_played  season_matches_in_squad  \
# 0                   1312                   24                       28
# 1                    836                   17                       28
# 2                   2247                   26                       27
#
#    total_minutes_played  total_games_played         dob  ...  \
# 0                  2148                  41   1/28/2000  ...
# 1                  2148                  41   1/28/2000  ...
# 2                 13368                 149  12/15/1989  ...
#
#    cumulative_games_played  minutes_per_game_prev_seasons  \
# 0                      NaN                            NaN
# ...

# %%
df.tail(5)
# Out:
#                   p_id2  start_year  season_days_injured  total_days_injured  \
# 1296      yoshinorimuto        2019                   46                 210
# 1297       yvesbissouma        2018                  124                 124
# 1298        zacksteffen        2020                   30                 307
# 1299  zlatanibrahimovic        2016                  210                 579
# 1300  zlatanibrahimovic        2017                   84                 579
#
#       season_minutes_played  season_games_played  season_matches_in_squad  \
# 1296                    288                    8                       17
# 1297                   1880                   28                       34
# 1298                     95                    1                       35
# 1299                   2577                   28                       28
# 1300                    122                    5                        8
#
# ...

# %%
df.describe()
# Out:
#         start_year  season_days_injured  total_days_injured  \
# count  1301.000000          1301.000000         1301.000000
# mean   2018.099923            79.050730          260.710992
# std       1.384810            84.578169          202.741896
# min    2016.000000             0.000000            3.000000
# 25%    2017.000000            24.000000          111.000000
# 50%    2018.000000            49.000000          210.000000
# 75%    2019.000000           103.000000          370.000000
# max    2020.000000           702.000000         2398.000000
#
#        season_minutes_played  season_games_played  season_matches_in_squad  \
# count            1301.000000          1301.000000              1301.000000
# mean             1483.156034            19.509608                25.089931
# std              1014.013920            11.099727                10.157698
# min                 0.000000             0.000000                 1.000000
# ...

# %%
df.describe(include="object")
# Out:
#             p_id2        dob nationality      work_rate  position
# count        1301       1301        1301           1301      1299
# unique        604        588          61              8         4
# top     bendavies  6/22/1993     England  Medium/Medium  Defender
# freq           24          9         551            434       492

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1301 entries, 0 to 1300
# Data columns (total 30 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   p_id2                              1301 non-null   object
#  1   start_year                         1301 non-null   int64
#  2   season_days_injured                1301 non-null   int64
#  3   total_days_injured                 1301 non-null   int64
#  4   season_minutes_played              1301 non-null   int64
#  5   season_games_played                1301 non-null   int64
#  6   season_matches_in_squad            1301 non-null   int64
#  7   total_minutes_played               1301 non-null   int64
#  8   total_games_played                 1301 non-null   int64
#  9   dob                                1301 non-null   object
#  10  height_cm                          1301 non-null   float64
# ...

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1296    False
# 1297    False
# 1298    False
# 1299    False
# 1300    False
# Length: 1301, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull()
# Out:
#       p_id2  start_year  season_days_injured  total_days_injured  \
# 0     False       False                False               False
# 1     False       False                False               False
# 2     False       False                False               False
# 3     False       False                False               False
# 4     False       False                False               False
# ...     ...         ...                  ...                 ...
# 1296  False       False                False               False
# 1297  False       False                False               False
# 1298  False       False                False               False
# 1299  False       False                False               False
# 1300  False       False                False               False
#
#       season_minutes_played  season_games_played  season_matches_in_squad  \
# 0                     False                False                    False
# ...

# %%
df.isnull().sum()
# Out:
# p_id2                                  0
# start_year                             0
# season_days_injured                    0
# total_days_injured                     0
# season_minutes_played                  0
# season_games_played                    0
# season_matches_in_squad                0
# total_minutes_played                   0
# total_games_played                     0
# dob                                    0
# height_cm                              0
# weight_kg                              0
# nationality                            0
# work_rate                              0
# pace                                  95
# physic                                95
# fifa_rating                            0
# position                               2
# age                                    0
# cumulative_minutes_played            604
# cumulative_games_played              604
# minutes_per_game_prev_seasons        616
# avg_days_injured_prev_seasons        604
# ...

# %%
df.dropna()
# Out:
#                   p_id2  start_year  season_days_injured  total_days_injured  \
# 1         aaronconnolly        2020                   71                 161
# 3        aaroncresswell        2018                   87                 226
# 4        aaroncresswell        2019                   35                 226
# 5        aaroncresswell        2020                    9                 226
# 7           aaronlennon        2018                  166                 199
# ...                 ...         ...                  ...                 ...
# 1291          yerrymina        2019                   54                 427
# 1292          yerrymina        2020                   83                 427
# 1294        yohancabaye        2017                   48                  64
# 1296      yoshinorimuto        2019                   46                 210
# 1300  zlatanibrahimovic        2017                   84                 579
#
# ...

# %%
df.dropna(axis =1 )
# Out:
#                   p_id2  start_year  season_days_injured  total_days_injured  \
# 0         aaronconnolly        2019                   13                 161
# 1         aaronconnolly        2020                   71                 161
# 2        aaroncresswell        2016                   95                 226
# 3        aaroncresswell        2018                   87                 226
# 4        aaroncresswell        2019                   35                 226
# ...                 ...         ...                  ...                 ...
# 1296      yoshinorimuto        2019                   46                 210
# 1297       yvesbissouma        2018                  124                 124
# 1298        zacksteffen        2020                   30                 307
# 1299  zlatanibrahimovic        2016                  210                 579
# 1300  zlatanibrahimovic        2017                   84                 579
#
# ...

# %%
df = df.bfill()

# %%
df
# Out:
#                   p_id2  start_year  season_days_injured  total_days_injured  \
# 0         aaronconnolly        2019                   13                 161
# 1         aaronconnolly        2020                   71                 161
# 2        aaroncresswell        2016                   95                 226
# 3        aaroncresswell        2018                   87                 226
# 4        aaroncresswell        2019                   35                 226
# ...                 ...         ...                  ...                 ...
# 1296      yoshinorimuto        2019                   46                 210
# 1297       yvesbissouma        2018                  124                 124
# 1298        zacksteffen        2020                   30                 307
# 1299  zlatanibrahimovic        2016                  210                 579
# 1300  zlatanibrahimovic        2017                   84                 579
#
# ...

# %%
df.isnull().sum()
# Out:
# p_id2                                0
# start_year                           0
# season_days_injured                  0
# total_days_injured                   0
# season_minutes_played                0
# season_games_played                  0
# season_matches_in_squad              0
# total_minutes_played                 0
# total_games_played                   0
# dob                                  0
# height_cm                            0
# weight_kg                            0
# nationality                          0
# work_rate                            0
# pace                                 0
# physic                               0
# fifa_rating                          0
# position                             0
# age                                  0
# cumulative_minutes_played            0
# cumulative_games_played              0
# minutes_per_game_prev_seasons        0
# avg_days_injured_prev_seasons        0
# avg_games_per_season_prev_seasons    0
# ...

# %%
df.to_csv("injury_output.csv" , index = False)
